# %% [markdown]
# # 01: Prompt Generation Test
#
# This notebook is for testing and refining the prompt generation agents defined in `src/prompt_engineering.py`.
#
# **Goal:** To generate a variety of creative and relevant prompts for each of our three themes (Fire, Water, Earth) that can be fed into the MusicGen model.

# %% [markdown]
# ## 1. Imports
#
# First, we need to import our custom prompt agent classes from the `src` directory. We also need to make sure Python can find our `src` folder.

# %%
import sys
import os

# Add the 'src' directory to the Python path
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.prompt_engineering import FirePromptAgent, WaterPromptAgent, EarthPromptAgent

# %% [markdown]
# ## 2. Initialize the Agents
#
# Now, let's create an instance of each of our themed agents.

# %%
fire_agent = FirePromptAgent()
water_agent = WaterPromptAgent()
earth_agent = EarthPromptAgent()

# %% [markdown]
# ## 3. Generate and View Prompts
#
# Let's generate a few prompts for each theme to see the variety.

# %%
print("--- FIRE PROMPTS ---")
for _ in range(3):
    print(f"- {fire_agent.generate_prompt()}\n")
# Out:
# --- FIRE PROMPTS ---
# - An atmospheric soundscape featuring burning embers, perfect for concentrating.
#
# - Generative music with hints of warm glow and a serene feeling.
#
# - A meditation track with gentle flame and smoldering.

# %%
print("--- WATER PROMPTS ---")
for _ in range(3):
    print(f"- {water_agent.generate_prompt()}\n")
# Out:
# --- WATER PROMPTS ---
# - A generative music track with underwater ambience and deep.
#
# - A soundscape track with underwater ambience and fluid.
#
# - An atmospheric soundscape featuring bubbling spring, perfect for sleeping.

# %%
print("--- EARTH PROMPTS ---")
for _ in range(3):
    print(f"- {earth_agent.generate_prompt()}\n")
# Out:
# --- EARTH PROMPTS ---
# - Deep focus track with serene sounds of the deep woods at night elements.
#
# - An atmospheric soundscape featuring sounds of the deep woods at night, perfect for studying.
#
# - grounding earth tones mixed with lofi chill sounds.

# %% [markdown]
# ## Next Steps
#
# From here, we can:
# *   Refine the vocabularies in `prompt_engineering.py` to get even better prompts.
# *   Start integrating these prompts with our audio generation script.
# *   Begin planning the batch generation process.
